# %%
import pandas as pd
import pickle
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix

# %%
# Load datasets
myntra = pd.read_csv('processed_data/clean_myntra.csv')
ratings = pd.read_csv('ratings.csv')

# %%
ratings.head()
# Out:
#    Unnamed: 0  userId  product_id  Rating
# 0           0    3269           0    4.30
# 1           1    4575           0    3.95
# 2           2    3844           0    3.72
# 3           3    1260           0    3.98
# 4           4    5298           0    4.37

# %%
# Drop unnecessery column
ratings.drop('Unnamed: 0', axis=1, inplace=True)

# %%
ratings
# Out:
#          userId  product_id  Rating
# 0          3269           0    4.30
# 1          4575           0    3.95
# 2          3844           0    3.72
# 3          1260           0    3.98
# 4          5298           0    4.37
# ...         ...         ...     ...
# 2419073    4732        8770    4.48
# 2419074    4117        8770    4.33
# 2419075    5459        8770    4.19
# 2419076     818        8770    4.78
# 2419077    4817        8770    4.67
#
# [2419078 rows x 3 columns]

# %%
# Merge ratings dataset with myntra using product_id
myntra_merge_ratings = ratings.merge(myntra, on="product_id")
myntra_merge_ratings.head(1)
# Out:
#    userId  product_id  Rating  Unnamed: 0 size  brand dominant_material  \
# 0    3269           0     4.3           0   XL  IMARA         Polyester
#
#                          title actual_color dominant_color  ...  \
# 0  IMARA Women Black Solid Top        Black          Black  ...
#
#   variant_compare_at_price ideal_for inventory Pre_Inventory  \
# 0                     1599     Women                     NaN
#
#                                      preprocess_body  \
# 0  black solid woven regular top has a v neck thr...
#
#                                                 img1  \
# 0  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img2  \
# 0  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img3  \
# 0  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img4  \
# 0  http://assets.myntassets.com/v1/assets/images/...
#
#                                           corpusData
# 0  IMARA Women Black Solid Top Black solid woven ...
#
# [1 rows x 26 columns]

# %%
myntra_merge_ratings.drop('Unnamed: 0', axis=1, inplace=True)

# %%
myntra_merge_ratings.head(1)
# Out:
#    userId  product_id  Rating size  brand dominant_material  \
# 0    3269           0     4.3   XL  IMARA         Polyester
#
#                          title actual_color dominant_color product_type  ...  \
# 0  IMARA Women Black Solid Top        Black          Black          Top  ...
#
#   variant_compare_at_price ideal_for inventory Pre_Inventory  \
# 0                     1599     Women                     NaN
#
#                                      preprocess_body  \
# 0  black solid woven regular top has a v neck thr...
#
#                                                 img1  \
# 0  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img2  \
# 0  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img3  \
# 0  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img4  \
# 0  http://assets.myntassets.com/v1/assets/images/...
#
#                                           corpusData
# 0  IMARA Women Black Solid Top Black solid woven ...
#
# [1 rows x 25 columns]

# %%
# Total Number of counts on each products
ratingCount = (myntra_merge_ratings.groupby(by=['title'])['Rating'].count().reset_index().rename(columns={'Rating': "TotalCountRating"})[["title", "TotalCountRating"]])

# %%
ratingCount
# Out:
#                                                   title  TotalCountRating
# 0      Jaipur Kurti Women Blue Printed Maxi Flared S...               270
# 1       20Dresses Women Black & Blue Printed Maxi Dress               292
# 2     A.T.U.N All Things Uber Nice Girls Mustard Yel...               269
# 3     AASI - HOUSE OF NAYO Women Blue & Rust Orange ...               284
# 4     AASI - HOUSE OF NAYO Women Navy Blue Solid Fit...               301
# ...                                                 ...               ...
# 5570  studio rasa Black & Gold-Coloured Hand Block-P...               283
# 5571  studio rasa Navy Blue & Off-White Handblock Pr...               278
# 5572  studio rasa Women Gold-Coloured Embroidered Fl...               309
# 5573  studio rasa Women Navy-Blue & Green Flared Max...               282
# 5574  studio rasa Yellow & Off-White Handblock Print...               284
#
# [5575 rows x 2 columns]

# %%
# Average product rating on each product
averageRating = (myntra_merge_ratings.groupby(by=['title'])['Rating'].mean().reset_index().rename(columns={'Rating': "AverageRatingCount"})[["title", "AverageRatingCount"]])

# %%
averageRating
# Out:
#                                                   title  AverageRatingCount
# 0      Jaipur Kurti Women Blue Printed Maxi Flared S...            4.266667
# 1       20Dresses Women Black & Blue Printed Maxi Dress            4.226096
# 2     A.T.U.N All Things Uber Nice Girls Mustard Yel...            4.258141
# 3     AASI - HOUSE OF NAYO Women Blue & Rust Orange ...            4.241092
# 4     AASI - HOUSE OF NAYO Women Navy Blue Solid Fit...            4.213821
# ...                                                 ...                 ...
# 5570  studio rasa Black & Gold-Coloured Hand Block-P...            4.258481
# 5571  studio rasa Navy Blue & Off-White Handblock Pr...            4.266259
# 5572  studio rasa Women Gold-Coloured Embroidered Fl...            4.231942
# 5573  studio rasa Women Navy-Blue & Green Flared Max...            4.247092
# 5574  studio rasa Yellow & Off-White Handblock Print...            4.252394
#
# [5575 rows x 2 columns]

# %%
# Find all the product index with ratings
titles = ratingCount['title']
idx = []

for title in titles:
    new_df = myntra[myntra['title'] == title]
    idx.append(new_df.index)

prod_idx = []
for i in idx:
    prod_idx.append(i[0])
len(prod_idx)
# Out:
# 5575

# %%
# remove all products without ratings
myntra = myntra.iloc[prod_idx]
myntra.drop('Unnamed: 0', axis=1, inplace=True)
myntra.reset_index(drop=True, inplace=True)
myntra
# Out:
#       product_id     size                         brand dominant_material  \
# 0            525       34                  Jaipur Kurti            cotton
# 1           4769        M                     20Dresses     Viscose Rayon
# 2           4147     1-2Y  A.T.U.N All Things Uber Nice         polyester
# 3           2782        S          AASI - HOUSE OF NAYO            Cotton
# 4           6202        L          AASI - HOUSE OF NAYO            Cotton
# ...          ...      ...                           ...               ...
# 5570        1740        M                   studio rasa          Chanderi
# 5571        1455        S                   studio rasa            Dupion
# 5572        7407  Onesize                   studio rasa            Dupion
# 5573        5797  Onesize                   studio rasa              Silk
# 5574        4097        S                   studio rasa            Dupion
#
#                                                   title  \
# 0      Jaipur Kurti Women Blue Printed Maxi Flared S...
# 1       20Dresses Women Black & Blue Printed Maxi Dress
# 2     A.T.U.N All Things Uber Nice Girls Mustard Yel...
# 3     AASI - HOUSE OF NAYO Women Blue & Rust Orange ...
# 4     AASI - HOUSE OF NAYO Women Navy Blue Solid Fit...
# ...                                                 ...
# 5570  studio rasa Black & Gold-Coloured Hand Block-P...
# 5571  studio rasa Navy Blue & Off-White Handblock Pr...
# 5572  studio rasa Women Gold-Coloured Embroidered Fl...
# 5573  studio rasa Women Navy-Blue & Green Flared Max...
# 5574  studio rasa Yellow & Off-White Handblock Print...
#
#                    actual_color dominant_color  \
# 0                          Blue           Blue
# 1                  Black | Blue          Black
# 2     Yellow | Maroon | Mustard        Mustard
# 3          Blue | Rust | Orange           Blue
# 4                   Blue | Navy           Navy
# ...                         ...            ...
# 5570                      Black          Black
# 5571                Blue | Navy           Navy
# 5572                        NaN            NaN
# 5573                      Green          Green
# 5574                     Yellow         Yellow
#
#                            product_type  \
# 0                     Maxi Flared Skirt
# 1                            Maxi Dress
# 2            Lehenga Choli with Dupatta
# 3                            Maxi Dress
# 4                     Fit & Flare Dress
# ...                                 ...
# 5570  Ready to Wear Lehenga with Blouse
# 5571  Ready to Wear Lehenga with Blouse
# 5572                         Maxi Skirt
# 5573                         Maxi Skirt
# 5574  Ready to Wear Lehenga with Blouse
#
#                                                    body  \
# 0     Blue woven printed maxi flared skirt, has an e...
# 1     Black and blue printed woven maxi dress, has a...
# 2     Mustard yellow and maroon lehenga choli with d...
# 3     Blue, rust orange and white printed woven maxi...
# 4     Navy Blue and mustard yellow solid woven fit a...
# ...                                                 ...
# 5570  Black and gold-toned embroidered lehenga choli...
# 5571  Navy Blue and off-white handblock print leheng...
# 5572  Gold-coloured woven maxi skirt with embroidere...
# 5573  Navy blue and green woven flared maxi skirt wi...
# 5574  Yellow and off-white handblock print lehenga c...
#
#                                         product_details  ...  \
# 0     Blue woven printed maxi flared skirt, has an e...  ...
# 1     Black and blue printed woven maxi dress, has a...  ...
# 2     Mustard yellow and maroon lehenga choli with d...  ...
# 3     Blue, rust orange and white printed woven maxi...  ...
# 4     Navy Blue and mustard yellow solid woven fit a...  ...
# ...                                                 ...  ...
# 5570  Black and gold-toned embroidered lehenga choli...  ...
# 5571  Navy Blue and off-white handblock print leheng...  ...
# 5572  Gold-coloured woven maxi skirt with embroidere...  ...
# 5573  Navy blue and green woven flared maxi skirt wi...  ...
# 5574  Yellow and off-white handblock print lehenga c...  ...
#
#      variant_compare_at_price ideal_for  \
# 0                        2299     Women
# 1                        1895     Women
# 2                        2999     Girls
# 3                        1699     Women
# 4                        1299     Women
# ...                       ...       ...
# 5570                     4999     Women
# 5571                     4599     Women
# 5572                     4299     Women
# 5573                     2999     Women
# 5574                     4299     Women
#
#                                               inventory  \
# 0                                                    15
# 1     Knit or Woven : Woven | Transparency : Opaque ...
# 2     Dupatta Fabric : Net | Occasion : Festive | Nu...
# 3     Knit or Woven : Woven | Transparency : Opaque ...
# 4     Knit or Woven : Woven | Transparency : Opaque ...
# ...                                                 ...
# 5570  Occasion : Festive | Number of Components : 2 ...
# 5571  Occasion : Festive | Number of Components : 2 ...
# 5572  Knit or Woven : Woven | Transparency : Opaque ...
# 5573                                                 10
# 5574  Occasion : Festive | Number of Components : 2 ...
#
#                                           Pre_Inventory  \
# 0                                                    15
# 1     knit or woven woven transparency opaque shape ...
# 2     dupatta fabric net occasion festive number of ...
# 3     knit or woven woven transparency opaque shape ...
# 4     knit or woven woven transparency opaque shape ...
# ...                                                 ...
# 5570  occasion festive number of components 2 blouse...
# 5571  occasion festive number of components 2 blouse...
# 5572  knit or woven woven transparency opaque closur...
# 5573                                                 10
# 5574  occasion festive number of components 2 blouse...
#
#                                         preprocess_body  \
# 0     blue woven printed maxi flared skirt has an el...
# 1     black and blue printed woven maxi dress has a ...
# 2     mustard yellow and maroon lehenga choli with d...
# 3     blue rust orange and white printed woven maxi ...
# 4     navy blue and mustard yellow solid woven fit a...
# ...                                                 ...
# 5570  black and gold toned embroidered lehenga choli...
# 5571  navy blue and off white handblock print leheng...
# 5572  gold coloured woven maxi skirt with embroidere...
# 5573  navy blue and green woven flared maxi skirt wi...
# 5574  yellow and off white handblock print lehenga c...
#
#                                                    img1  \
# 0     http://assets.myntassets.com/v1/assets/images/...
# 1     http://assets.myntassets.com/v1/assets/images/...
# 2     http://assets.myntassets.com/v1/assets/images/...
# 3     http://assets.myntassets.com/v1/assets/images/...
# 4     http://assets.myntassets.com/v1/assets/images/...
# ...                                                 ...
# 5570  http://assets.myntassets.com/v1/assets/images/...
# 5571  http://assets.myntassets.com/v1/assets/images/...
# 5572  http://assets.myntassets.com/v1/assets/images/...
# 5573  http://assets.myntassets.com/v1/assets/images/...
# 5574  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img2  \
# 0     http://assets.myntassets.com/v1/assets/images/...
# 1     http://assets.myntassets.com/v1/assets/images/...
# 2     http://assets.myntassets.com/v1/assets/images/...
# 3     http://assets.myntassets.com/v1/assets/images/...
# 4     http://assets.myntassets.com/v1/assets/images/...
# ...                                                 ...
# 5570  http://assets.myntassets.com/v1/assets/images/...
# 5571  http://assets.myntassets.com/v1/assets/images/...
# 5572  http://assets.myntassets.com/v1/assets/images/...
# 5573  http://assets.myntassets.com/v1/assets/images/...
# 5574  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img3  \
# 0     http://assets.myntassets.com/v1/assets/images/...
# 1     http://assets.myntassets.com/v1/assets/images/...
# 2     http://assets.myntassets.com/v1/assets/images/...
# 3     http://assets.myntassets.com/v1/assets/images/...
# 4     http://assets.myntassets.com/v1/assets/images/...
# ...                                                 ...
# 5570  http://assets.myntassets.com/v1/assets/images/...
# 5571  http://assets.myntassets.com/v1/assets/images/...
# 5572  http://assets.myntassets.com/v1/assets/images/...
# 5573  http://assets.myntassets.com/v1/assets/images/...
# 5574  http://assets.myntassets.com/v1/assets/images/...
#
#                                                    img4  \
# 0     http://assets.myntassets.com/v1/assets/images/...
# 1     http://assets.myntassets.com/v1/assets/images/...
# 2     http://assets.myntassets.com/v1/assets/images/...
# 3     http://assets.myntassets.com/v1/assets/images/...
# 4     http://assets.myntassets.com/v1/assets/images/...
# ...                                                 ...
# 5570  http://assets.myntassets.com/v1/assets/images/...
# 5571  http://assets.myntassets.com/v1/assets/images/...
# 5572  http://assets.myntassets.com/v1/assets/images/...
# 5573  http://assets.myntassets.com/v1/assets/images/...
# 5574  http://assets.myntassets.com/v1/assets/images/...
#
#                                              corpusData
# 0      Jaipur Kurti Women Blue Printed Maxi Flared S...
# 1     20Dresses Women Black & Blue Printed Maxi Dres...
# 2     A.T.U.N All Things Uber Nice Girls Mustard Yel...
# 3     AASI - HOUSE OF NAYO Women Blue & Rust Orange ...
# 4     AASI - HOUSE OF NAYO Women Navy Blue Solid Fit...
# ...                                                 ...
# 5570  studio rasa Black & Gold-Coloured Hand Block-P...
# 5571  studio rasa Navy Blue & Off-White Handblock Pr...
# 5572  studio rasa Women Gold-Coloured Embroidered Fl...
# 5573  studio rasa Women Navy-Blue & Green Flared Max...
# 5574  studio rasa Yellow & Off-White Handblock Print...
#
# [5575 rows x 23 columns]

# %%
myntra_with_ratings = myntra.merge(averageRating, on='title')
myntra_with_ratings.to_csv('processed_data/myntra_with_ratings.csv')

# %%
# merge totalRating and average Rating
rating_df = ratingCount.merge(averageRating, on="title")
rating_df
# Out:
#                                                   title  TotalCountRating  \
# 0      Jaipur Kurti Women Blue Printed Maxi Flared S...               270
# 1       20Dresses Women Black & Blue Printed Maxi Dress               292
# 2     A.T.U.N All Things Uber Nice Girls Mustard Yel...               269
# 3     AASI - HOUSE OF NAYO Women Blue & Rust Orange ...               284
# 4     AASI - HOUSE OF NAYO Women Navy Blue Solid Fit...               301
# ...                                                 ...               ...
# 5570  studio rasa Black & Gold-Coloured Hand Block-P...               283
# 5571  studio rasa Navy Blue & Off-White Handblock Pr...               278
# 5572  studio rasa Women Gold-Coloured Embroidered Fl...               309
# 5573  studio rasa Women Navy-Blue & Green Flared Max...               282
# 5574  studio rasa Yellow & Off-White Handblock Print...               284
#
#       AverageRatingCount
# 0               4.266667
# 1               4.226096
# 2               4.258141
# 3               4.241092
# 4               4.213821
# ...                  ...
# 5570            4.258481
# 5571            4.266259
# 5572            4.231942
# 5573            4.247092
# 5574            4.252394
#
# [5575 rows x 3 columns]

# %%
# merge ratings with myntra_merge_ratings
main_data = rating_df.merge(myntra_merge_ratings, on="title")
main_data.head(2)
# Out:
#                                                title  TotalCountRating  \
# 0   Jaipur Kurti Women Blue Printed Maxi Flared S...               270
# 1   Jaipur Kurti Women Blue Printed Maxi Flared S...               270
#
#    AverageRatingCount  userId  product_id  Rating size         brand  \
# 0            4.266667    3321         525    3.62   34  Jaipur Kurti
# 1            4.266667    3233         525    4.66   34  Jaipur Kurti
#
#   dominant_material actual_color  ... variant_compare_at_price ideal_for  \
# 0            cotton         Blue  ...                     2299     Women
# 1            cotton         Blue  ...                     2299     Women
#
#   inventory Pre_Inventory                                    preprocess_body  \
# 0        15            15  blue woven printed maxi flared skirt has an el...
# 1        15            15  blue woven printed maxi flared skirt has an el...
#
#                                                 img1  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img2  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img3  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                                 img4  \
# 0  http://assets.myntassets.com/v1/assets/images/...
# 1  http://assets.myntassets.com/v1/assets/images/...
#
#                                           corpusData
# 0   Jaipur Kurti Women Blue Printed Maxi Flared S...
# 1   Jaipur Kurti Women Blue Printed Maxi Flared S...
#
# [2 rows x 27 columns]

# %%
# Create pivot matrix
pivot_Matrix = main_data.pivot_table(index='title', columns='userId', values='Rating').fillna(0)
pivot_Matrix
# Out:
# userId                                              1     2     3     4     \
# title
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt   0.0   0.0   0.0   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress      0.0   0.0   0.0   0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...   0.0   0.0   0.0   0.0
# AASI - HOUSE OF NAYO Women Blue & Rust Orange P...   0.0   0.0   0.0   0.0
# AASI - HOUSE OF NAYO Women Navy Blue Solid Fit ...   0.0   0.0   0.0   0.0
# ...                                                  ...   ...   ...   ...
# studio rasa Black & Gold-Coloured Hand Block-Pr...   0.0   0.0   0.0   0.0
# studio rasa Navy Blue & Off-White Handblock Pri...   0.0   0.0   0.0   0.0
# studio rasa Women Gold-Coloured Embroidered Fla...   0.0   0.0   0.0   0.0
# studio rasa Women Navy-Blue & Green Flared Maxi...   0.0   0.0   0.0   0.0
# studio rasa Yellow & Off-White Handblock Print ...   0.0   0.0   0.0   0.0
#
# userId                                              5     6     7     8     \
# title
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt   0.0   0.0  0.00   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress      0.0   0.0  0.00   0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...   0.0   0.0  0.00   0.0
# AASI - HOUSE OF NAYO Women Blue & Rust Orange P...   0.0   0.0  0.00   0.0
# AASI - HOUSE OF NAYO Women Navy Blue Solid Fit ...   0.0   0.0  0.00   0.0
# ...                                                  ...   ...   ...   ...
# studio rasa Black & Gold-Coloured Hand Block-Pr...   0.0   0.0  0.00   0.0
# studio rasa Navy Blue & Off-White Handblock Pri...   0.0   0.0  0.00   0.0
# studio rasa Women Gold-Coloured Embroidered Fla...   0.0   0.0  0.00   0.0
# studio rasa Women Navy-Blue & Green Flared Maxi...   0.0   0.0  3.85   0.0
# studio rasa Yellow & Off-White Handblock Print ...   0.0   0.0  0.00   0.0
#
# userId                                              9     10    ...  7990  \
# title                                                           ...
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt  0.00   0.0  ...  4.87
# 20Dresses Women Black & Blue Printed Maxi Dress     0.00   0.0  ...  0.00
# A.T.U.N All Things Uber Nice Girls Mustard Yell...  0.00   0.0  ...  0.00
# AASI - HOUSE OF NAYO Women Blue & Rust Orange P...  0.00   0.0  ...  0.00
# AASI - HOUSE OF NAYO Women Navy Blue Solid Fit ...  0.00   0.0  ...  0.00
# ...                                                  ...   ...  ...   ...
# studio rasa Black & Gold-Coloured Hand Block-Pr...  0.00   0.0  ...  0.00
# studio rasa Navy Blue & Off-White Handblock Pri...  0.00   0.0  ...  0.00
# studio rasa Women Gold-Coloured Embroidered Fla...  0.00   0.0  ...  0.00
# studio rasa Women Navy-Blue & Green Flared Maxi...  4.28   0.0  ...  0.00
# studio rasa Yellow & Off-White Handblock Print ...  0.00   0.0  ...  0.00
#
# userId                                              7991  7992  7993  7994  \
# title
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt   0.0  0.00   0.0   0.0
# 20Dresses Women Black & Blue Printed Maxi Dress      0.0  0.00   0.0   0.0
# A.T.U.N All Things Uber Nice Girls Mustard Yell...   0.0  0.00   0.0   0.0
# AASI - HOUSE OF NAYO Women Blue & Rust Orange P...   0.0  0.00   0.0   0.0
# AASI - HOUSE OF NAYO Women Navy Blue Solid Fit ...   0.0  0.00   0.0   0.0
# ...                                                  ...   ...   ...   ...
# studio rasa Black & Gold-Coloured Hand Block-Pr...   0.0  0.00   0.0   0.0
# studio rasa Navy Blue & Off-White Handblock Pri...   0.0  3.93   0.0   0.0
# studio rasa Women Gold-Coloured Embroidered Fla...   0.0  0.00   0.0   0.0
# studio rasa Women Navy-Blue & Green Flared Maxi...   0.0  0.00   0.0   0.0
# studio rasa Yellow & Off-White Handblock Print ...   0.0  0.00   0.0   0.0
#
# userId                                              7995  7996  7997  7998  \
# title
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt  0.00  0.00   0.0  0.00
# 20Dresses Women Black & Blue Printed Maxi Dress     0.00  0.00   0.0  0.00
# A.T.U.N All Things Uber Nice Girls Mustard Yell...  3.63  0.00   0.0  0.00
# AASI - HOUSE OF NAYO Women Blue & Rust Orange P...  0.00  0.00   0.0  0.00
# AASI - HOUSE OF NAYO Women Navy Blue Solid Fit ...  0.00  0.00   4.2  0.00
# ...                                                  ...   ...   ...   ...
# studio rasa Black & Gold-Coloured Hand Block-Pr...  0.00  3.79   0.0  0.00
# studio rasa Navy Blue & Off-White Handblock Pri...  0.00  0.00   0.0  0.00
# studio rasa Women Gold-Coloured Embroidered Fla...  0.00  0.00   0.0  0.00
# studio rasa Women Navy-Blue & Green Flared Maxi...  0.00  0.00   0.0  3.93
# studio rasa Yellow & Off-White Handblock Print ...  0.00  0.00   0.0  0.00
#
# userId                                              7999
# title
#  Jaipur Kurti Women Blue Printed Maxi Flared Skirt  0.00
# 20Dresses Women Black & Blue Printed Maxi Dress     0.00
# A.T.U.N All Things Uber Nice Girls Mustard Yell...  3.87
# AASI - HOUSE OF NAYO Women Blue & Rust Orange P...  0.00
# AASI - HOUSE OF NAYO Women Navy Blue Solid Fit ...  0.00
# ...                                                  ...
# studio rasa Black & Gold-Coloured Hand Block-Pr...  0.00
# studio rasa Navy Blue & Off-White Handblock Pri...  0.00
# studio rasa Women Gold-Coloured Embroidered Fla...  0.00
# studio rasa Women Navy-Blue & Green Flared Maxi...  0.00
# studio rasa Yellow & Off-White Handblock Print ...  0.00
#
# [5575 rows x 7994 columns]

# %%
main_matrix = csr_matrix(pivot_Matrix.values)

model_knn = NearestNeighbors(metric="cosine", algorithm="brute")
model_knn.fit(main_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
# Find distances and indices for every products
distances, indices = model_knn.kneighbors(pivot_Matrix.iloc[0:].values, n_neighbors=7)

# %%
indices
# Out:
# array([[   0, 3107, 1581, ..., 2785, 2509,  405],
#        [   1, 5469, 3161, ..., 4181,  589, 3415],
#        [   2, 4960, 2563, ..., 4250, 3061, 2900],
#        ...,
#        [5572, 4589, 1400, ..., 3429, 4094, 2168],
#        [5573, 3483, 3145, ..., 1796, 5280, 4030],
#        [5574, 4045,  393, ..., 3634,  555, 5477]], dtype=int64)

# %%
# Dump pickle files
pickle.dump(pivot_Matrix.index, open('pickle_files/pivot_matrix.pkl', 'wb'))
pickle.dump(indices, open('pickle_files/filtered_indices.pkl', 'wb'))
